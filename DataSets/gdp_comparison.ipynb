# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#files to load
country_gdp_load = "DP_LIVE_11012020191937707.csv"
country_gdp = pd.read_csv(country_gdp_load)

country_gdp
# Out:
#     LOCATION  TIME        Value
# 0        AUS  2006  773963.6385
# 1        AUS  2007  824725.9546
# 2        AUS  2008  851983.1297
# 3        AUS  2009  902707.1812
# 4        AUS  2010  942682.5259
# ..       ...   ...          ...
# 212      ZMB  2012   52572.6872
# 213      ZMB  2013   56090.0667
# 214      ZMB  2014   59768.5152
# 215      ZMB  2015   62184.1302
# 216      ZMB  2016   65325.8997
#
# [217 rows x 3 columns]

# %%
#PIVOT!
country_gdp = country_gdp.pivot_table(values ="Value", index ="LOCATION", columns ="TIME")
country_gdp
# Out:
# TIME              2006          2007          2008          2009  \
# LOCATION
# ARG       6.025078e+05  6.744225e+05  7.154361e+05  6.782241e+05
# AUS       7.739636e+05  8.247260e+05  8.519831e+05  9.027072e+05
# BGR       8.660910e+04  9.656631e+04  1.074113e+05  1.056231e+05
# CHN       7.692796e+06  9.023650e+06  1.008729e+07  1.111960e+07
# COL       3.903769e+05  4.283172e+05  4.508704e+05  4.597840e+05
# DEU       2.810613e+06  2.982138e+06  3.103958e+06  3.018203e+06
# FRA       2.063203e+06  2.182049e+06  2.259256e+06  2.246074e+06
# GBR       2.115106e+06  2.182920e+06  2.265856e+06  2.181538e+06
# GRC       3.142424e+05  3.236076e+05  3.418178e+05  3.375242e+05
# IDN       1.639527e+06  1.790392e+06  1.934980e+06  1.999105e+06
# IND       3.800566e+06  4.237565e+06  4.466325e+06  4.837456e+06
# ITA       1.884706e+06  1.993081e+06  2.089717e+06  2.046840e+06
# JPN       4.230714e+06  4.416228e+06  4.456434e+06  4.250983e+06
# ...

# %%
#find mean

for column in country_gdp:
    total = country_gdp.sum(axis = 1, skipna = True)
    mean = total*100/10
    country_gdp["Mean"] = mean
    
loc_mean = pd.DataFrame({"Mean GDP":mean})
loc_mean = loc_mean.sort_values(by=['Mean GDP'])
loc_mean = loc_mean.reset_index()    
loc_mean
# Out:
#    LOCATION      Mean GDP
# 0       ZMB  5.856190e+16
# 1       BGR  1.401683e+17
# 2       PER  2.692204e+17
# 3       GRC  3.743862e+17
# 4       COL  6.557309e+17
# 5       ARG  9.495423e+17
# 6       POL  1.026285e+18
# 7       AUS  1.205960e+18
# 8       SAU  1.678386e+18
# 9       TUR  1.789475e+18
# 10      MEX  2.316462e+18
# 11      ITA  2.610522e+18
# 12      IDN  2.777400e+18
# 13      GBR  2.968302e+18
# 14      FRA  2.984544e+18
# 15      DEU  4.166603e+18
# 16      JPN  5.702776e+18
# 17      IND  7.278498e+18
# 18      CHN  1.732460e+19
# 19      USA  1.949020e+19

# %%
#ploterate

plt.bar(loc_mean['LOCATION'],loc_mean['Mean GDP'], color=['lavender','lime','yellow','olive','navy','teal','blue','maroon','pink','magenta','orange','green','cyan','grey','beige','red','brown','lightgrey','lightgreen','purple'])
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
