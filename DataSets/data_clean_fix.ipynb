# %%
#import dependencies
import pandas as pd
import numpy as np

#files to load
country_gdp_load = "country_gdp_2006_2016.csv"
export_data_load = "LivestockMeat_Exports.csv"
import_data_load = "LivestockMeat_Imports.csv"

country_gdp = pd.read_csv(country_gdp_load)
export_data = pd.read_csv(export_data_load)
import_data = pd.read_csv(import_data_load)

export_data.head()
# Out:
#    SOURCE_ID      HS_CODE                                     COMMODITY_DESC  \
# 0         63  202306000.0  Meat of bovine animals, boneless, except proce...
# 1         63  202306000.0  Meat of bovine animals, boneless, except proce...
# 2         63  202306000.0  Meat of bovine animals, boneless, except proce...
# 3         63  202306000.0  Meat of bovine animals, boneless, except proce...
# 4         63  202306000.0  Meat of bovine animals, boneless, except proce...
#
#    GEOGRAPHY_CODE        GEOGRAPHY_DESC  ATTRIBUTE_DESC UNIT_DESC  YEAR_ID  \
# 0            2771  Netherlands Antilles  US Export, QTY       CWE     1991
# 1            2771  Netherlands Antilles  US Export, QTY       CWE     1992
# 2            2771  Netherlands Antilles  US Export, QTY       CWE     1992
# 3            2771  Netherlands Antilles  US Export, QTY       CWE     1992
# 4            2771  Netherlands Antilles  US Export, QTY       CWE     1992
#
#    TIMEPERIOD_ID        AMOUNT
# ...

# %%
#cut unneeded columns
to_cut = ['SOURCE_ID','HS_CODE','GEOGRAPHY_CODE','ATTRIBUTE_DESC', 'TIMEPERIOD_ID']
#table_country_export = export_data
export_data.drop(to_cut, inplace=True, axis=1)

# %%
#sort by country and year
sorted_exports = export_data.sort_values(['GEOGRAPHY_DESC','YEAR_ID'])
sorted_exports.head(50)
# Out:
#                                             COMMODITY_DESC GEOGRAPHY_DESC  \
# 735386                                             Broiler    Afghanistan
# 1109346  *Chicken Cuts and Edible Offal (Ex Livers), Fr...    Afghanistan
# 1109348  *Chicken Cuts and Edible Offal (Ex Livers), Fr...    Afghanistan
# 1170530                                            Broiler    Afghanistan
# 193436   *Chicken Cuts and Edible Offal (Ex Livers), Fr...    Afghanistan
# 443501                                             Broiler    Afghanistan
# 735589                                             Broiler    Afghanistan
# 1076875  *Chicken Cuts and Edible Offal (Ex Livers), Fr...    Afghanistan
# 193435   *Chicken Cuts and Edible Offal (Ex Livers), Fr...    Afghanistan
# 193437   *Chicken Cuts and Edible Offal (Ex Livers), Fr...    Afghanistan
# 193438   *Chicken Cuts and Edible Offal (Ex Livers), Fr...    Afghanistan
# 443502                                             Broiler    Afghanistan
# ...

# %%
#shrink data down to 2006 to 2016
sorted_exports = sorted_exports[sorted_exports['YEAR_ID'].between(2006, 2016)]
sorted_exports.head(50)
# Out:
#                                            COMMODITY_DESC GEOGRAPHY_DESC  \
# 19094   Meat and edible offal, of the poultry of headi...    Afghanistan
# 19095   Meat and edible offal, of the poultry of headi...    Afghanistan
# 19096   Meat and edible offal, of the poultry of headi...    Afghanistan
# 19097   Meat and edible offal, of the poultry of headi...    Afghanistan
# 19242   Meat and edible offal, of the poultry of headi...    Afghanistan
# 19243   Meat and edible offal, of the poultry of headi...    Afghanistan
# 19244   Meat and edible offal, of the poultry of headi...    Afghanistan
# 71392   Meat and edible offal, of the poultry of headi...    Afghanistan
# 103033                                          Shell egg    Afghanistan
# 105563                                               Pork    Afghanistan
# 259785  Meat and edible offal, of the poultry of headi...    Afghanistan
# 259885  Meat and edible offal, of the poultry of headi...    Afghanistan
# ...

# %%
#shrink data to only countries we are interested in
sorted_exports_2 = sorted_exports.loc[(sorted_exports["GEOGRAPHY_DESC"] == 'Argentina')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Australia')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'China (Mainland)')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Bulgaria')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Colombia')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'France')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Germany, Fed. Republic')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Greece')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'India')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Indonesia')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Italy')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Japan')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Mexico')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Peru')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Poland')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Saudi Arabia')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Turkey')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'United Kingdom')|
                                  (sorted_exports["GEOGRAPHY_DESC"] == 'Zambia'),:]
sorted_exports_2
# Out:
#                                             COMMODITY_DESC GEOGRAPHY_DESC  \
# 26074    Meat of bovine animals, frozen, boneless, proc...      Argentina
# 26077    Meat of bovine animals, frozen, boneless, proc...      Argentina
# 104465   Meat and edible offal, of the poultry of headi...      Argentina
# 243485                                              Mutton      Argentina
# 286418   Sausages and similar products, of meat, meat o...      Argentina
# ...                                                    ...            ...
# 1148260                                               Pork         Zambia
# 47454       Meat of swine, nesoi, except processed, frozen         Zambia
# 85422       Meat of swine, nesoi, except processed, frozen         Zambia
# 266288                                                Pork         Zambia
# 1148259                                               Pork         Zambia
#
#         UNIT_DESC  YEAR_ID         AMOUNT
# ...

# %%
#save clean export data
sorted_exports_2.to_csv('exports_country_clean.csv')

# %%
import_data.head()
# Out:
#    SOURCE_ID       HS_CODE                                     COMMODITY_DESC  \
# 0         58  1.601006e+09  Sausage and similar product meat etc, nesoi, f...
# 1         58  1.601006e+09  Sausage and similar product meat etc, nesoi, f...
# 2         58  1.601006e+09  Sausage and similar product meat etc, nesoi, f...
# 3         58  1.601006e+09  Sausage and similar product meat etc, nesoi, f...
# 4         58  1.601006e+09  Sausage and similar product meat etc, nesoi, f...
#
#    GEOGRAPHY_CODE GEOGRAPHY_DESC  ATTRIBUTE_DESC UNIT_DESC  YEAR_ID  \
# 0            1220         Canada  US Import, QTY        KG     2006
# 1            1220         Canada  US Import, QTY        KG     2006
# 2            1220         Canada  US Import, QTY        KG     2007
# 3            1220         Canada  US Import, QTY        KG     2007
# 4            1220         Canada  US Import, QTY        KG     2008
#
#    TIMEPERIOD_ID   AMOUNT
# 0              9  11641.0
# 1             10  14786.0
# ...

# %%
#cut excess columns from import_data
import_data.drop(to_cut, inplace=True, axis=1)

# %%
#sort by country and year
sorted_imports = import_data.sort_values(['GEOGRAPHY_DESC','YEAR_ID'])
sorted_imports.head(50)
# Out:
#                                            COMMODITY_DESC GEOGRAPHY_DESC  \
# 27119                                                Pork        Algeria
# 27120                                                Pork        Algeria
# 218308     Meat of swine, nesoi, except processed, frozen        Algeria
# 234937     Meat of swine, nesoi, except processed, frozen        Algeria
# 197     Meat of bovine animals, nesoi, no cereals or v...      Argentina
# 198     Meat of bovine animals, nesoi, no cereals or v...      Argentina
# 199     Meat of bovine animals, nesoi, no cereals or v...      Argentina
# 200     Meat of bovine animals, nesoi, no cereals or v...      Argentina
# 201     Meat of bovine animals, nesoi, no cereals or v...      Argentina
# 8761                                                 Pork      Argentina
# 14644   Meat of bovine animals, salted, in brine, drie...      Argentina
# 14645   Meat of bovine animals, salted, in brine, drie...      Argentina
# ...

# %%
#shrink data to 2006-2016
sorted_imports = sorted_imports[sorted_imports['YEAR_ID'].between(2006, 2016)]

# %%
#shrink data to only countries we are interested in
sorted_imports_2 = sorted_imports.loc[(sorted_imports["GEOGRAPHY_DESC"] == 'Argentina')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Australia')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'China (Mainland)')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Bulgaria')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Colombia')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'France')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Germany, Fed. Republic')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Greece')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'India')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Indonesia')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Italy')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Japan')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Mexico')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Peru')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Poland')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Saudi Arabia')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Turkey')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'United Kingdom')|
                                  (sorted_imports["GEOGRAPHY_DESC"] == 'Zambia'),:]
sorted_imports_2
# Out:
#                                            COMMODITY_DESC  GEOGRAPHY_DESC  \
# 30128   Meat of bovine animals, cured or pickled, no c...       Argentina
# 30129   Meat of bovine animals, cured or pickled, no c...       Argentina
# 30150   Corned beef, nesoi, no cereals or vegetables, ...       Argentina
# 30151   Corned beef, nesoi, no cereals or vegetables, ...       Argentina
# 30152   Corned beef, nesoi, no cereals or vegetables, ...       Argentina
# ...                                                   ...             ...
# 217405     Meat of swine, nesoi, except processed, frozen  United Kingdom
# 217425     Meat of swine, nesoi, except processed, frozen  United Kingdom
# 217426     Meat of swine, nesoi, except processed, frozen  United Kingdom
# 217427     Meat of swine, nesoi, except processed, frozen  United Kingdom
# 217428     Meat of swine, nesoi, except processed, frozen  United Kingdom
#
#        UNIT_DESC  YEAR_ID    AMOUNT
# 30128         KG     2006  137101.0
# ...

# %%
#save clean export data
sorted_imports_2.to_csv('imports_country_clean.csv')

# %%
country_gdp.head()
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value Flag Codes
# 0      AUS       GDP     TOT  USD_CAP         A  2006  37844.782088        NaN
# 1      AUS       GDP     TOT  USD_CAP         A  2007  39597.743117        NaN
# 2      AUS       GDP     TOT  USD_CAP         A  2008  40094.833205        NaN
# 3      AUS       GDP     TOT  USD_CAP         A  2009  41615.326657        NaN
# 4      AUS       GDP     TOT  USD_CAP         A  2010  42787.358539        NaN

# %%
#cut unneeded columns
to_drop = ['INDICATOR','SUBJECT','FREQUENCY','MEASURE','Flag Codes']
country_gdp.drop(to_drop, inplace=True, axis=1)
country_gdp
# Out:
#     LOCATION  TIME         Value
# 0        AUS  2006  37844.782088
# 1        AUS  2007  39597.743117
# 2        AUS  2008  40094.833205
# 3        AUS  2009  41615.326657
# 4        AUS  2010  42787.358539
# ..       ...   ...           ...
# 630      ZMB  2012   3576.373281
# 631      ZMB  2013   3701.581648
# 632      ZMB  2014   3826.164471
# 633      ZMB  2015   3862.128452
# 634      ZMB  2016   3937.429913
#
# [635 rows x 3 columns]

# %%
#Shrink data to countries being studied
cleaned_gdp = country_gdp.loc[(country_gdp["LOCATION"] == 'ARG')|
                              (country_gdp["LOCATION"] == 'AUS')|
                              (country_gdp["LOCATION"] == 'BGR')|
                              (country_gdp["LOCATION"] == 'CHN')|
                              (country_gdp["LOCATION"] == 'COL')|
                              (country_gdp["LOCATION"] == 'FRA')|
                              (country_gdp["LOCATION"] == 'DEU')|
                              (country_gdp["LOCATION"] == 'GRC')|
                              (country_gdp["LOCATION"] == 'IND')|
                              (country_gdp["LOCATION"] == 'IDN')|
                              (country_gdp["LOCATION"] == 'ITA')|
                              (country_gdp["LOCATION"] == 'JPN')|
                              (country_gdp["LOCATION"] == 'MEX')|
                              (country_gdp["LOCATION"] == 'PER')|
                              (country_gdp["LOCATION"] == 'POL')|
                              (country_gdp["LOCATION"] == 'SAU')|
                              (country_gdp["LOCATION"] == 'TUR')|
                              (country_gdp["LOCATION"] == 'GBR')|
                              (country_gdp["LOCATION"] == 'USA')|
                              (country_gdp["LOCATION"] == 'ZMB'),:]
cleaned_gdp
# Out:
#     LOCATION  TIME         Value
# 0        AUS  2006  37844.782088
# 1        AUS  2007  39597.743117
# 2        AUS  2008  40094.833205
# 3        AUS  2009  41615.326657
# 4        AUS  2010  42787.358539
# ..       ...   ...           ...
# 630      ZMB  2012   3576.373281
# 631      ZMB  2013   3701.581648
# 632      ZMB  2014   3826.164471
# 633      ZMB  2015   3862.128452
# 634      ZMB  2016   3937.429913
#
# [217 rows x 3 columns]

# %%
cleaned_gdp.to_csv('cleaned_gdp.csv')

# %%
cleaned_gdp_2 = cleaned_gdp.pivot_table(values ="Value", index ="TIME", columns ="LOCATION")

# %%
cleaned_gdp_2
# Out:
# LOCATION           ARG           AUS           BGR           CHN  \
# TIME
# 2006      15460.414115  37844.782088  11249.366255   5852.349553
# 2007      17136.460230  39597.743117  12606.956513   6829.424541
# 2008      18000.203145  40094.833205  14089.687690   7595.734210
# 2009      16898.991717  41615.326657  13925.023858   8332.410641
# 2010      18524.856760  42787.358539  14598.585504   9281.496213
# 2011      19817.450480  44419.309749  15661.192150  10330.747358
# 2012      19764.225013  43879.180355  16241.607310  11300.296497
# 2013      20365.613348  47761.214060  16581.780416  12331.055894
# 2014      20008.320642  47638.633438  17555.515868  13411.503995
# 2015      20551.833194  47351.047292  18342.039892  14419.244821
# 2016      20130.408028  50309.405732  20009.538590  15467.890286
#
# LOCATION           COL           DEU           FRA           GBR  \
# TIME
# 2006       8993.624772  34624.968884  32435.702917  34772.478459
# ...

# %%
#rename to match import/export data
cleaned_gdp_2 = cleaned_gdp_2.rename(columns = {'ARG':'Argentina',
                                     'AUS':'Australia',
                                     'BGR':'Bulgaria',
                                     'CHN':'China (Mainland)',
                                     'COL':'Colombia',
                                     'FRA':'France',
                                     'DEU':'Germany, Fed. Republic',
                                     'GRC':'Greece',
                                     'IND':'India',
                                     'IDN':'Indonesia',
                                     'ITA':'Italy',
                                     'JPN':'Japna',
                                     'MEX':'Mexico',
                                     'PER':'Peru',
                                     'POL':'Poland',
                                     'SAU':'Saudi Arabia',
                                     'TUR':'Turkey',
                                     'GBR':'United Kingdom',
                                     'USA':'United States',
                                     'ZMB':'Zambia'})
cleaned_gdp_2
# Out:
# LOCATION     Argentina     Australia      Bulgaria  China (Mainland)  \
# TIME
# 2006      15460.414115  37844.782088  11249.366255       5852.349553
# 2007      17136.460230  39597.743117  12606.956513       6829.424541
# 2008      18000.203145  40094.833205  14089.687690       7595.734210
# 2009      16898.991717  41615.326657  13925.023858       8332.410641
# 2010      18524.856760  42787.358539  14598.585504       9281.496213
# 2011      19817.450480  44419.309749  15661.192150      10330.747358
# 2012      19764.225013  43879.180355  16241.607310      11300.296497
# 2013      20365.613348  47761.214060  16581.780416      12331.055894
# 2014      20008.320642  47638.633438  17555.515868      13411.503995
# 2015      20551.833194  47351.047292  18342.039892      14419.244821
# 2016      20130.408028  50309.405732  20009.538590      15467.890286
#
# LOCATION      Colombia  Germany, Fed. Republic        France  United Kingdom  \
# TIME
# ...

# %%
cleaned_gdp_2.to_csv('cleaned_gdp_match.csv')
