# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load in datasets
conversion_new_load_import = "final_clean_imports.csv"
conversion_new_load_export = "final_clean_exports.csv"

# read in csv

new_import_df = pd.read_csv(conversion_new_load_import)
new_export_df = pd.read_csv(conversion_new_load_export)

# see if it works

new_import_df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1 Commodity    Country UNIT_DESC  Year  \
# 0            0         30128      Beef  Argentina        KG  2006
# 1            1         30129      Beef  Argentina        KG  2006
# 2            2         30150      Beef  Argentina        KG  2006
# 3            3         30151      Beef  Argentina        KG  2006
# 4            4         30152      Beef  Argentina        KG  2006
# 5            5         30153      Beef  Argentina        KG  2006
# 6            6         30154      Beef  Argentina        KG  2006
# 7            7         30207      Beef  Argentina       CWE  2006
# 8            8         30208      Beef  Argentina       CWE  2006
# 9            9         30261      Beef  Argentina        KG  2006
# 10          10         30262      Beef  Argentina        KG  2006
# 11          11         30263      Beef  Argentina        KG  2006
# 12          12         30264      Beef  Argentina        KG  2006
# ...

# %%
new_export_df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1 Commodity    Country UNIT_DESC  Year  \
# 0        15282         26074      Beef  Argentina        KG  2006
# 1        15283         26077      Beef  Argentina       CWE  2006
# 2        15284        104465   Chicken  Argentina        KG  2006
# 3        15285        243485     Sheep  Argentina       CWE  2006
# 4        15286        286418      Pork  Argentina        KG  2006
# 5        15287        286561      Pork  Argentina        KG  2006
# 6        15288        360353      Beef  Argentina       CWE  2006
# 7        15289        421427      Pork  Argentina       CWE  2006
# 8        15290        421602      Pork  Argentina        KG  2006
# 9        15291        431041      Pork  Argentina        KG  2006
# 10       15292        431044      Pork  Argentina        KG  2006
# 11       15293        431045      Pork  Argentina        KG  2006
# 12       15294        431046      Pork  Argentina        KG  2006
# ...

# %%
grouped_export_df = new_export_df.groupby(['Country'])
grouped_export_df.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1 Commodity    Country UNIT_DESC  Year  \
# 0           15282         26074      Beef  Argentina        KG  2006
# 1           15283         26077      Beef  Argentina       CWE  2006
# 2           15284        104465   Chicken  Argentina        KG  2006
# 3           15285        243485     Sheep  Argentina       CWE  2006
# 4           15286        286418      Pork  Argentina        KG  2006
# ...           ...           ...       ...        ...       ...   ...
# 81052      527818         78399      Pork     Zambia        KG  2007
# 81053      527819        125720      Beef     Zambia        KG  2007
# 81054      527820        266287      Pork     Zambia       CWE  2007
# 81055      527821        453229   Chicken     Zambia       CWE  2007
# 81056      527822        565081      Beef     Zambia       CWE  2007
#
#              AMOUNT  Metric Tons
# 0      11210.000000    11.210000
# 1      33708.898999  1529.035659
# 2       4920.000000     4.920000
# ...

# %%
grouped_export_df.nunique()
# Out:
#                         Unnamed: 0  Unnamed: 0.1  Commodity  Country  \
# Country
# Argentina                      297           297          5        1
# Australia                     4936          4936          5        1
# Bulgaria                       378           378          5        1
# China (Mainland)              6245          6245          5        1
# Colombia                      7823          7823          6        1
# France                        2238          2238          5        1
# Germany, Fed. Republic        5771          5771          6        1
# Greece                        1722          1722          5        1
# India                          494           494          4        1
# Indonesia                     1998          1998          4        1
# Italy                         4249          4249          5        1
# Japan                        11368         11368          6        1
# ...

# %%
grouped_export_df.describe()
# Out:
#                        Unnamed: 0                                              \
#                             count      mean          std       min        25%
# Country
# Argentina                   297.0   15430.0    85.880731   15282.0   15356.00
# Australia                  4936.0   27274.5  1425.044795   24807.0   26040.75
# Bulgaria                    378.0   79353.5   109.263443   79165.0   79259.25
# China (Mainland)           6245.0  112606.0  1802.920547  109484.0  111045.00
# Colombia                   7823.0  127723.0  2258.449911  123812.0  125767.50
# France                     2238.0  182287.5   646.199273  181169.0  181728.25
# Germany, Fed. Republic     5771.0  194844.0  1666.088533  191959.0  193401.50
# Greece                     1722.0  199894.5   497.242898  199034.0  199464.25
# India                       494.0  249127.5   142.749781  248881.0  249004.25
# Indonesia                  1998.0  250373.5   576.917238  249375.0  249874.25
# ...

# %%
grouped_import_df = new_import_df.groupby(['Country'])
grouped_import_df.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1 Commodity         Country UNIT_DESC  Year  \
# 0               0         30128      Beef       Argentina        KG  2006
# 1               1         30129      Beef       Argentina        KG  2006
# 2               2         30150      Beef       Argentina        KG  2006
# 3               3         30151      Beef       Argentina        KG  2006
# 4               4         30152      Beef       Argentina        KG  2006
# ...           ...           ...       ...             ...       ...   ...
# 22045       66079         30633      Pork  United Kingdom       CWE  2006
# 22046       66080         30634      Pork  United Kingdom       CWE  2006
# 22047       66081         30739      Pork  United Kingdom       CWE  2006
# 22048       66082         30740      Pork  United Kingdom       CWE  2006
# 22049       66083         31919      Pork  United Kingdom        KG  2006
#
#               AMOUNT   Metric Tons
# 0      137101.000000    137.101000
# ...

# %%
grouped_import_df.nunique()
# Out:
#                         Unnamed: 0  Unnamed: 0.1  Commodity  Country  \
# Country
# Argentina                      982           982          1        1
# Australia                     6757          6757          6        1
# China (Mainland)               807           807          4        1
# Colombia                        17            17          3        1
# France                         773           773          4        1
# Germany, Fed. Republic        1028          1028          4        1
# Greece                           3             3          1        1
# India                            8             8          1        1
# Italy                         2231          2231          4        1
# Japan                         1218          1218          4        1
# Mexico                        5830          5830          5        1
# Peru                             4             4          1        1
# ...

# %%
grouped_import_df.describe()
# Out:
#                        Unnamed: 0                                           \
#                             count     mean          std      min       25%
# Country
# Argentina                   982.0    490.5   283.623283      0.0    245.25
# Australia                  6757.0   4360.0  1950.722217    982.0   2671.00
# China (Mainland)            807.0  32848.0   233.105126  32445.0  32646.50
# Colombia                     17.0  34150.0     5.049752  34142.0  34146.00
# France                      773.0  38462.0   223.290170  38076.0  38269.00
# Germany, Fed. Republic     1028.0  39362.5   296.902341  38849.0  39105.75
# Greece                        3.0  39878.0     1.000000  39877.0  39877.50
# India                         8.0  41399.5     2.449490  41396.0  41397.75
# Italy                      2231.0  43809.0   644.178547  42694.0  43251.50
# Japan                      1218.0  45537.5   351.750622  44929.0  45233.25
# ...

# %%
# Collecting a list of all columns within the DataFrame
new_import_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Commodity', 'Country', 'UNIT_DESC',
#        'Year', 'AMOUNT', 'Metric Tons'],
#       dtype='object')

# %%
new_export_df["Country"].value_counts()
# Out:
# Mexico                    20693
# Japan                     11368
# Colombia                   7823
# China (Mainland)           6245
# Germany, Fed. Republic     5771
# Australia                  4936
# Peru                       4274
# Italy                      4249
# Saudi Arabia               3318
# United Kingdom             2945
# France                     2238
# Indonesia                  1998
# Turkey                     1965
# Greece                     1722
# India                       494
# Bulgaria                    378
# Poland                      338
# Argentina                   297
# Zambia                       33
# Name: Country, dtype: int64

# %%
new_export_df["Country"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        Argentina
# 1        Argentina
# 2        Argentina
# 3        Argentina
# 4        Argentina
#            ...
# 81080       Zambia
# 81081       Zambia
# 81082       Zambia
# 81083       Zambia
# 81084       Zambia
# Name: Country, Length: 81085, dtype: object>

# %%
grouped_export_df = new_export_df.groupby(['Country'])
grouped_export_df.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1 Commodity    Country UNIT_DESC  Year  \
# 0           15282         26074      Beef  Argentina        KG  2006
# 1           15283         26077      Beef  Argentina       CWE  2006
# 2           15284        104465   Chicken  Argentina        KG  2006
# 3           15285        243485     Sheep  Argentina       CWE  2006
# 4           15286        286418      Pork  Argentina        KG  2006
# ...           ...           ...       ...        ...       ...   ...
# 81052      527818         78399      Pork     Zambia        KG  2007
# 81053      527819        125720      Beef     Zambia        KG  2007
# 81054      527820        266287      Pork     Zambia       CWE  2007
# 81055      527821        453229   Chicken     Zambia       CWE  2007
# 81056      527822        565081      Beef     Zambia       CWE  2007
#
#              AMOUNT  Metric Tons
# 0      11210.000000    11.210000
# 1      33708.898999  1529.035659
# 2       4920.000000     4.920000
# ...

# %%
grouped_export_commodity_df = new_export_df.groupby(['Commodity'])
grouped_export_commodity_df.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1 Commodity                 Country UNIT_DESC  \
# 0           15282         26074      Beef               Argentina        KG
# 1           15283         26077      Beef               Argentina       CWE
# 2           15284        104465   Chicken               Argentina        KG
# 3           15285        243485     Sheep               Argentina       CWE
# 4           15286        286418      Pork               Argentina        KG
# 5           15287        286561      Pork               Argentina        KG
# 6           15288        360353      Beef               Argentina       CWE
# 7           15289        421427      Pork               Argentina       CWE
# 8           15290        421602      Pork               Argentina        KG
# 9           15291        431041      Pork               Argentina        KG
# 13          15295        519935      Beef               Argentina       CWE
# ...

# %%
grouped_export_commodity_df.nunique()
# Out:
#            Unnamed: 0  Unnamed: 0.1  Commodity  Country  UNIT_DESC  Year  \
# Commodity
# Beef            16196         16196          1       19          3    11
# Chicken         29623         29623          1       19          3    11
# Goat              112           112          1        4          1     9
# Pork            24134         24134          1       19          3    11
# Sheep            2682          2682          1       16          3    11
# Turkey           8338          8338          1       19          2    11
#
#            AMOUNT  Metric Tons
# Commodity
# Beef        14548        14681
# Chicken     23383        23517
# Goat           56           56
# Pork        22042        22099
# Sheep        1807         1813
# Turkey       7238         7238

# %%
grouped_import_df = new_import_df.groupby(['Country'])
grouped_import_df.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1 Commodity         Country UNIT_DESC  Year  \
# 0               0         30128      Beef       Argentina        KG  2006
# 1               1         30129      Beef       Argentina        KG  2006
# 2               2         30150      Beef       Argentina        KG  2006
# 3               3         30151      Beef       Argentina        KG  2006
# 4               4         30152      Beef       Argentina        KG  2006
# ...           ...           ...       ...             ...       ...   ...
# 22045       66079         30633      Pork  United Kingdom       CWE  2006
# 22046       66080         30634      Pork  United Kingdom       CWE  2006
# 22047       66081         30739      Pork  United Kingdom       CWE  2006
# 22048       66082         30740      Pork  United Kingdom       CWE  2006
# 22049       66083         31919      Pork  United Kingdom        KG  2006
#
#               AMOUNT   Metric Tons
# 0      137101.000000    137.101000
# ...

# %%
grouped_import_df.nunique()
# Out:
#                         Unnamed: 0  Unnamed: 0.1  Commodity  Country  \
# Country
# Argentina                      982           982          1        1
# Australia                     6757          6757          6        1
# China (Mainland)               807           807          4        1
# Colombia                        17            17          3        1
# France                         773           773          4        1
# Germany, Fed. Republic        1028          1028          4        1
# Greece                           3             3          1        1
# India                            8             8          1        1
# Italy                         2231          2231          4        1
# Japan                         1218          1218          4        1
# Mexico                        5830          5830          5        1
# Peru                             4             4          1        1
# ...
